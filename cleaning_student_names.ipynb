# %%
# Add the Pandas dependency
import pandas as pd

# %%
# Files to load
student_data_to_load = "C:/Users/cly19/OneDrive/Desktop/Class_/School_District_Analysis/Resources/students_complete.csv"

# %%
student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Put the student name in a list.

student_names = student_data_df["student_name"].tolist()
student_names
# Out:
# ['Paul Bradley',
#  'Victor Smith',
#  'Kevin Rodriguez',
#  'Dr. Richard Scott',
#  'Bonnie Ray',
#  'Bryan Miranda',
#  'Sheena Carter',
#  'Nicole Baker',
#  'Michael Roth',
#  'Matthew Greene',
#  'Andrew Alexander',
#  'Daniel Cooper',
#  'Brittney Walker',
#  'William Long',
#  'Tammy Hebert',
#  'Dr. Jordan Carson',
#  'Donald Zamora',
#  'Kimberly Santiago',
#  'Kevin Stevens',
#  'Brandi Lyons',
#  'Lisa Davis',
#  'Kristen Lopez',
#  'Kimberly Stewart',
#  'Christopher Parker',
#  'Chelsea Griffith',
#  'Cesar Morris',
#  'Melanie Decker',
#  'Tracey Oconnor',
#  'Kelly James',
#  'Nicole Brown',
#  'Bobby Harris',
#  'Brian Fernandez',
#  'Candace Phelps',
#  'Amy Gonzalez',
#  'Steven Green',
#  'Benjamin Carlson',
#  'Kevin Bailey',
#  'Jesse Newton',
#  'Kimberly Mercado',
#  'Gregory Roberts',
#  'Matthew Mayer',
#  'Jennifer Parks',
#  'John Carlson',
#  'Megan Roberts',
#  'Debra Flores',
#  'Heidi Jackson',
#  'Denise Bradford',
#  'Ellen Brown',
#  'Amy Perkins',
# ...

# %%
# Split the student name and determine the length of the split name.

for student_name in student_names:
    
    print(student_name.split(), len(name.split()))
# Out:
# ['Paul', 'Bradley'] 3
# ['Victor', 'Smith'] 3
# ['Kevin', 'Rodriguez'] 3
# ['Dr.', 'Richard', 'Scott'] 3
# ['Bonnie', 'Ray'] 3
# ['Bryan', 'Miranda'] 3
# ['Sheena', 'Carter'] 3
# ['Nicole', 'Baker'] 3
# ['Michael', 'Roth'] 3
# ['Matthew', 'Greene'] 3
# ['Andrew', 'Alexander'] 3
# ['Daniel', 'Cooper'] 3
# ['Brittney', 'Walker'] 3
# ['William', 'Long'] 3
# ['Tammy', 'Hebert'] 3
# ['Dr.', 'Jordan', 'Carson'] 3
# ['Donald', 'Zamora'] 3
# ['Kimberly', 'Santiago'] 3
# ['Kevin', 'Stevens'] 3
# ['Brandi', 'Lyons'] 3
# ['Lisa', 'Davis'] 3
# ['Kristen', 'Lopez'] 3
# ['Kimberly', 'Stewart'] 3
# ['Christopher', 'Parker'] 3
# ['Chelsea', 'Griffith'] 3
# ['Cesar', 'Morris'] 3
# ['Melanie', 'Decker'] 3
# ['Tracey', 'Oconnor'] 3
# ['Kelly', 'James'] 3
# ['Nicole', 'Brown'] 3
# ['Bobby', 'Harris'] 3
# ['Brian', 'Fernandez'] 3
# ['Candace', 'Phelps'] 3
# ['Amy', 'Gonzalez'] 3
# ['Steven', 'Green'] 3
# ['Benjamin', 'Carlson'] 3
# ['Kevin', 'Bailey'] 3
# ['Jesse', 'Newton'] 3
# ...

# %%
# Creat a new list and use it for the for loop to iterate thru the list.

students_to_fix = []

# Use an if statement to check the length of the name.
# If the name is greater than or equal to "3", add the name to the list.

for name in student_names:
    if len(name.split()) >= 3:
        students_to_fix.append(name)
        
# Get the length of the students whose names are greater than or equal to "3".
len(students_to_fix)

print(students_to_fix)
# Out:
# ['Dr. Richard Scott', 'Dr. Jordan Carson', 'Madeline Snyder MD', 'Mr. Dylan Taylor MD', 'Dr. Scott Gill', 'Miss Madison Everett', 'Virginia Ramirez MD', 'Joseph Morales III', 'Angela Perkins DVM', 'Heather Allen MD', 'Luke Lowery MD', 'Dr. Larry Hines', 'Emily Cardenas MD', 'Mrs. Elizabeth Espinoza DDS', 'Mrs. Lisa Becker', 'Mr. Travis Young', 'Paula Fernandez DVM', 'Dr. Xavier Bell II', 'Andrew Hanson MD', 'Mr. Roberto Wright MD', 'Mr. Dale Miller', 'Mary Gonzalez DDS', 'Mrs. Cindy Brown', 'James White MD', 'Donald Gill DDS', 'Mrs. Catherine Williams MD', 'Ashley Caldwell MD', 'Mr. Jared Campbell', 'Michael Moreno PhD', 'Tara Parker MD', 'Shawn Williams DVM', 'Dr. Alicia Martinez', 'Mr. Timothy Anderson', 'Mrs. Paula Lee', 'Mr. Elijah Hall', 'Mr. Raymond Stone', 'John Dickerson MD', 'Mr. Alex Franklin', 'Mrs. Jessica Dunn', 'Mr. Michael Stevenson', 'Jason Jones DDS', 'Adriana Wade MD', 'Erica Hurley MD', 'Dr. Garrett Wright', 'Mr. James Allen', 'Mr. Timothy Harper MD', 'Dale Brown M
# ...

# %%
# Add the prefixes less than or equal to 4 to a new list.

prefixes = []

for name in students_to_fix:
    
    if len(name.split()[0]) <= 4:
        
        prefixes.append(name.split()[0])
        
print(prefixes)
# Out:
# ['Dr.', 'Dr.', 'Mr.', 'Dr.', 'Miss', 'Luke', 'Dr.', 'Mrs.', 'Mrs.', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Mary', 'Mrs.', 'Mrs.', 'Mr.', 'Tara', 'Dr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'John', 'Mr.', 'Mrs.', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Dale', 'Dr.', 'Dr.', 'Dr.', 'Ms.', 'Dr.', 'Dr.', 'Mr.', 'Mrs.', 'Amy', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Mrs.', 'Mrs.', 'Mr.', 'Lisa', 'Mr.', 'Dr.', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Mr.', 'Mark', 'Mrs.', 'Dr.', 'Dr.', 'Miss', 'Mr.', 'Miss', 'Mr.', 'Mrs.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Dr.', 'Miss', 'Mr.', 'Mrs.', 'Mr.', 'Tara', 'Dr.', 'Mr.', 'Cody', 'Mr.', 'Dr.', 'Mr.', 'Ms.', 'Dr.', 'Mr.', 'Mrs.', 'Sara', 'Mr.', 'Mrs.', 'Dr.', 'Mr.', 'Dr.', 'Mr.', 'Mrs.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Mrs.', 'Mr.', 'Mrs.', 'Dr.', 'Ryan', 'Mrs.', 'Mr.', 'Ms.', 'Mr.', 'Dr.', 'John', 'Mr.', 'Dr.', 'Dr.', 'Mrs.', 'Dr.', 'Mrs.', 'Mr.', 'Mr.', 'Mrs.', 'Dr.', 'Dr.', 'Miss', 'Miss', 'Mr.', 'Mr.', 'Mr.', 'Dr.', 'Dr.', 'Mrs.', 'Mr.', 'Ms.', 'Mr.', 'Miss', 'Tony', 'Dr.', 'M
# ...

# %%
# add the suffixes less than or equal to 3 to a new list.

suffixes = []

for name in students_to_fix:
    if len(name.split()[-1]) <= 3:
        suffixes.append(name.split()[-1])
        
print(suffixes)
# Out:
# ['MD', 'MD', 'MD', 'III', 'DVM', 'MD', 'MD', 'MD', 'DDS', 'DVM', 'II', 'MD', 'MD', 'DDS', 'MD', 'DDS', 'MD', 'MD', 'PhD', 'MD', 'DVM', 'Lee', 'MD', 'DDS', 'MD', 'MD', 'MD', 'MD', 'MD', 'MD', 'DDS', 'Jr.', 'DVM', 'MD', 'MD', 'PhD', 'IV', 'MD', 'DDS', 'DDS', 'DDS', 'MD', 'DDS', 'MD', 'DVM', 'IV', 'MD', 'DDS', 'MD', 'MD', 'DVM', 'Jr.', 'MD', 'PhD', 'II', 'MD', 'DDS', 'DDS', 'DDS', 'Jr.', 'III', 'MD', 'MD', 'MD', 'DDS', 'Jr.', 'DDS', 'DVM', 'DDS', 'DVM', 'MD', 'DDS', 'PhD', 'DDS', 'DDS', 'Jr.', 'Jr.', 'DVM', 'DDS', 'MD', 'MD', 'DVM', 'DDS', 'DVM', 'Jr.', 'MD', 'Jr.', 'MD', 'PhD', 'PhD', 'DDS', 'MD', 'DDS', 'DVM', 'Cox', 'DVM', 'MD', 'Jr.', 'MD', 'DDS', 'MD', 'MD', 'DDS', 'DDS', 'Roy', 'DDS', 'DDS', 'DDS', 'II', 'PhD', 'MD', 'PhD', 'DDS', 'MD', 'DDS', 'Jr.', 'Day', 'DDS', 'MD', 'PhD', 'DDS', 'Jr.', 'DDS', 'MD', 'MD', 'MD', 'MD', 'DDS', 'MD', 'DDS', 'PhD', 'DVM', 'DDS', 'MD', 'MD', 'MD', 'DDS', 'Jr.', 'Jr.', 'DDS', 'Jr.', 'MD', 'MD', 'PhD', 'PhD', 'DDS', 'MD', 'MD', 'III', 'DVM', 'PhD', 'J
# ...

# %%
# Get the unique items in the "prefixes" list.
set(prefixes)
# Out:
# {'Adam',
#  'Amy',
#  'Anna',
#  'Anne',
#  'Carl',
#  'Chad',
#  'Cody',
#  'Cory',
#  'Dale',
#  'Dana',
#  'Dawn',
#  'Dr.',
#  'Emma',
#  'Eric',
#  'Erik',
#  'Erin',
#  'Gail',
#  'Gary',
#  'Gina',
#  'Greg',
#  'Ian',
#  'Jill',
#  'Jodi',
#  'Joe',
#  'John',
#  'Jon',
#  'Jose',
#  'Judy',
#  'Kara',
#  'Kari',
#  'Kim',
#  'Kyle',
#  'Leah',
#  'Lisa',
#  'Lori',
#  'Luke',
#  'Lynn',
#  'Marc',
#  'Mark',
#  'Mary',
#  'Mike',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Ms.',
#  'Noah',
#  'Omar',
#  'Paul',
#  'Ruth',
#  'Ryan',
#  'Sara',
#  'Sean',
#  'Seth',
#  'Tara',
#  'Tina',
#  'Todd',
#  'Toni',
#  'Tony',
#  'Troy'}

# %%
# Get the unique items in the suffixes" list.
set(suffixes)
# Out:
# {'Cox',
#  'DDS',
#  'DVM',
#  'Day',
#  'II',
#  'III',
#  'IV',
#  'Jr.',
#  'Kim',
#  'Lee',
#  'Li',
#  'MD',
#  'PhD',
#  'Roy',
#  'V'}

# %%
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# %%
# Iterate through the "prefixes_suffixes" list and replace them with an empty space, "" when it appears in the student's name.

for word in prefixes_suffixes:
    
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")
# Out:
# C:\Users\cly19\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   """

# %%
student_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# 2                 90          60
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14044\2798835791.py in <module>
#       1 # Combine the data into a single dataset.
# ----> 2 school_data_complete_df = pd.merge(student_data_df, school_data_df, on=["school_name", "school_name"])
#       3 school_data_complete_df.head()
#
# NameError: name 'school_data_df' is not defined
